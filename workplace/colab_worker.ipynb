# %% [markdown]
# # Colab workplace — A100 worker
#
# This notebook is the GPU workplace. Cursor's gateway queues jobs on Drive; this worker runs them.
#
# 1. **Runtime → Change runtime type → GPU → A100**
# 2. Run all cells and leave the last cell running
# 3. In Cursor, open `http://127.0.0.1:8765` and queue train/eval

# %%
import torch

assert torch.cuda.is_available(), (
    "No GPU. Runtime → Change runtime type → GPU → A100, then reconnect."
)

name = torch.cuda.get_device_name(0)
print("GPU:", name)
if "A100" not in name:
    print("Warning: switch runtime type to A100.")
# Out:
# GPU: NVIDIA A100-SXM4-80GB

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U transformers accelerate peft bitsandbytes datasets pillow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 63.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.1/559.1 kB 44.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 143.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 53.3 MB/s eta 0:00:00

# %%
# !python /content/drive/MyDrive/gated_lora/workplace/worker.py
# Out:
# Workplace root: /content/drive/MyDrive/gated_lora
# Requested GPU: A100
# Visible GPU: NVIDIA A100-SXM4-80GB
# Heartbeat written.
# Colab workplace online.
# If this is a new runtime, the next step copies Qwen3-VL-8B to local SSD.
# Training waits until that copy finishes. Leave this cell running.
# Copying model from Drive to local SSD (several minutes, not idle)...
# From: /content/drive/MyDrive/gated_lora/models/Qwen3-VL-8B-Instruct
# To:   /content/Qwen3-VL-8B-Instruct
# Local model ready: /content/Qwen3-VL-8B-Instruct
# Waiting for Drive jobs...
# Running 157a35de1471 ['/usr/bin/python3', '/content/drive/MyDrive/gated_lora/scripts/train_gated_lora.py', '--model_name', '/content/Qwen3-VL-8B-Instruct', '--train_manifest', '/content/drive/MyDrive/gated_lora/data/manifests/train_80k.jsonl', '--eval_manifest', '/content/drive/MyDrive/gated_lora/data/manifests/eval_20k.jsonl', '--output_dir', '/content/drive/MyDrive/gated_lora/checkpoints/gated_qlora_r8', '--data_root', '/content/drive/MyDrive/gated_lora/data', '--lora_rank', '8', '--batch_size', '8', '--grad_accum', '4', '--epochs', '1', '--learning_rate', '0.0002', '--gate_init', '2.0', '--save_steps', '200', '--lora_alpha', '16']
